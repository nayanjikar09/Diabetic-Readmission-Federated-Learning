# %%
import matplotlib.pyplot as plt

scenarios = [
    "Centralized",
    "Hospital A",
    "Hospital B",
    "Hospital C",
    "Federated Ensemble"
]

auc = [0.6512, 0.5987, 0.6234, 0.6478, 0.8761]

plt.figure()
plt.bar(scenarios, auc)

plt.xlabel("Experimental Scenarios")
plt.ylabel("AUC-ROC")
plt.title("Comparative Performance Across Experimental Scenarios")
plt.xticks(rotation=20)
plt.show()
