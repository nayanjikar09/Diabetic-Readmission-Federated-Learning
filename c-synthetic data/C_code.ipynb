# %%
import pandas as pd

# Load original dataset
df = pd.read_csv(r"E:\semm 8\federated_learning\federated_3\data_preprosses\diabetic_data.csv")

# Generate another bootstrap sample (new dataset)
synthetic_df_3 = df.sample(
    n=len(df),
    replace=True,
    random_state=123   # new seed → new dataset
).reset_index(drop=True)

# Save it
synthetic_df_3.to_csv("C_synthetic_diabetic_data_v3.csv", index=False)

print("Third synthetic dataset generated successfully!")
# Out:
# Third synthetic dataset generated successfully!
